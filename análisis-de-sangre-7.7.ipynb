# %%
q = 0.99
[(i, 1-q**i+1/i) for i in range(1, 21)]
# Out:
# |  1 |                1.01 |
# |  2 |              0.5199 |
# |  3 |  0.3630343333333333 |
# |  4 | 0.28940399000000006 |
# |  5 |  0.2490099501000001 |
# |  6 | 0.22518651726566666 |
# |  7 | 0.21079179495015293 |
# |  8 | 0.20225530557207994 |
# |  9 | 0.19759386362747028 |
# | 10 |  0.1956179249911956 |
# | 11 | 0.19557083665037453 |
# | 12 | 0.19694846161720408 |
# | 13 |  0.1994020539241091 |
# | 14 |  0.2026827586595932 |
# | 15 | 0.20660831202537822 |
# | 16 | 0.21104222890512447 |
# | 17 | 0.21588033602783796 |
# | 18 | 0.22104179410546806 |
# | 19 | 0.22646295511178177 |
# | 20 | 0.23209306240276922 |
