# %%
from random import random

def repeticiones(n):
    total = 0
    for i in range(n):
        x = random()
        y = random()
        if x**2 + y**2 < 1:
            total = total + 1
    return 4*total/n

# %%
repeticiones(10000000)
